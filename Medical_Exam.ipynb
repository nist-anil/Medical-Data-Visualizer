# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
medical_exam=pd.read_csv(r"C:\Users\there\Desktop\DataAnalysis_Course\DataForDataAnalysis\medical_examination.csv")

# %%
medical_exam.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
medical_exam.tail(3)
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 69997      0     1       0       1
# 69998      0     0       0       1
# 69999      0     0       1       0

# %%
medical_exam.isnull()
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol   gluc  \
# 0      False  False   False   False   False  False  False        False  False
# 1      False  False   False   False   False  False  False        False  False
# 2      False  False   False   False   False  False  False        False  False
# 3      False  False   False   False   False  False  False        False  False
# 4      False  False   False   False   False  False  False        False  False
# ...      ...    ...     ...     ...     ...    ...    ...          ...    ...
# 69995  False  False   False   False   False  False  False        False  False
# 69996  False  False   False   False   False  False  False        False  False
# 69997  False  False   False   False   False  False  False        False  False
# 69998  False  False   False   False   False  False  False        False  False
# 69999  False  False   False   False   False  False  False        False  False
#
# ...

# %%
print(medical_exam.isnull().any())
# Out:
# id             False
# age            False
# gender         False
# height         False
# weight         False
# ap_hi          False
# ap_lo          False
# cholesterol    False
# gluc           False
# smoke          False
# alco           False
# active         False
# cardio         False
# dtype: bool

# %%
medical_exam.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349843    164.359229     74.205690
# std    28851.302323   2467.251667      0.477253      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      3.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
# Data Cleaning

# %%
# Find if dataset contain non-real values
medical_exam[~medical_exam.applymap(np.isreal).all(1)]
# Out:
# Empty DataFrame
# Columns: [id, age, gender, height, weight, ap_hi, ap_lo, cholesterol, gluc, smoke, alco, active, cardio]
# Index: []

# %%
medical_exam.applymap(np.isreal)
# Out:
#          id   age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0      True  True    True    True    True   True   True         True  True
# 1      True  True    True    True    True   True   True         True  True
# 2      True  True    True    True    True   True   True         True  True
# 3      True  True    True    True    True   True   True         True  True
# 4      True  True    True    True    True   True   True         True  True
# ...     ...   ...     ...     ...     ...    ...    ...          ...   ...
# 69995  True  True    True    True    True   True   True         True  True
# 69996  True  True    True    True    True   True   True         True  True
# 69997  True  True    True    True    True   True   True         True  True
# 69998  True  True    True    True    True   True   True         True  True
# 69999  True  True    True    True    True   True   True         True  True
#
#        smoke  alco  active  cardio
# ...

# %% [markdown]
# - Normalize the data by making 0 always good and 1 always bad. If the value of cholesterol or gluc is 1, make the value 0. If the value is more than 1, make the value 1.

# %%
medical_exam['cholesterol']= medical_exam['cholesterol'].apply(lambda x : 1 if x>1 else 0)
medical_exam['gluc']= medical_exam['gluc'].apply(lambda x : 1 if x>1 else 0)

# %%
medical_exam.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            0     0      0
# 1   1  20228       1     156    85.0    140     90            1     0      0
# 2   2  18857       1     165    64.0    130     70            1     0      0
# 3   3  17623       2     169    82.0    150    100            0     0      0
# 4   4  17474       1     156    56.0    100     60            0     0      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %% [markdown]
# - Add an overweight column to the data. To determine if a person is overweight, first calculate their BMI by dividing their weight in kilograms by the square of their height in meters. If that value is > 25 then the person is overweight. Use the value 0 for NOT overweight and the value 1 for overweight.

# %%
conditions = [
    ((medical_exam['weight']/(medical_exam['height']/100)**2) > 25),
    ((medical_exam['weight']/(medical_exam['height']/100)**2) < 25)
  
    ]

# create a list of the values we want to assign for each condition
values = ['1', '0']

# create a new column and use np.select to assign values to it using our lists as arguments
medical_exam['Overweight']=np.select(conditions, values)

# display updated DataFram
medical_exam.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            0     0      0
# 1   1  20228       1     156    85.0    140     90            1     0      0
# 2   2  18857       1     165    64.0    130     70            1     0      0
# 3   3  17623       2     169    82.0    150    100            0     0      0
# 4   4  17474       1     156    56.0    100     60            0     0      0
#
#    alco  active  cardio Overweight
# 0     0       1       0          0
# 1     0       1       1          1
# 2     0       0       1          0
# 3     0       1       1          1
# 4     0       0       0          0

# %%
medical_exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
#  13  Overweight   70000 non-null  object
# dtypes: float64(1), int64(12), object(1)
# memory usage: 7.5+ MB

# %%
medical_exam.Overweight = medical_exam.Overweight.astype('float').astype('Int64')

# %%
medical_exam['weight'] = medical_exam['weight'].astype(np.int64)

# %%
medical_exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  int64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
#  13  Overweight   70000 non-null  Int64
# dtypes: Int64(1), int64(13)
# memory usage: 7.5 MB

# %%
medical_exam.loc[medical_exam['cholesterol']> 1, 'cholesterol'].count()
# Out:
# 0

# %%
medical_exam.loc[medical_exam['cholesterol']< 0, 'cholesterol'].count()
# Out:
# 0

# %%
medical_exam.loc[medical_exam['gluc']> 1, 'gluc'].count()
# Out:
# 0

# %%
medical_exam.loc[medical_exam['gluc']< 0, 'gluc'].count()
# Out:
# 0

# %% [markdown]
# - Convert the data into long format and create a chart that shows the value counts of the categorical features using seaborn's catplot(). The dataset should be split by 'Cardio' so there is one chart for each cardio value.

# %%
# Reshape Data
medical_exam_r=pd.melt(medical_exam, id_vars=['cardio'], value_vars=['active','alco','cholesterol', 'gluc', 'Overweight', 'smoke'], value_name='Total')
medical_exam_r
# Out:
#         cardio variable Total
# 0            0   active     1
# 1            1   active     1
# 2            1   active     0
# 3            1   active     1
# 4            0   active     0
# ...        ...      ...   ...
# 419995       0    smoke     1
# 419996       1    smoke     0
# 419997       1    smoke     0
# 419998       1    smoke     0
# 419999       0    smoke     0
#
# [420000 rows x 3 columns]

# %%
medical_exam_r.columns
# Out:
# Index(['cardio', 'variable', 'Total'], dtype='object')

# %%
# Catplot()
import seaborn as sns
sns.catplot(x='variable',hue='Total', col='cardio', kind='count',  data=medical_exam_r)

# %% [markdown]
# ## Clean the data. Filter out the following patient segments that represent incorrect data:
# - diastolic pressure is higher than systolic (Keep the correct data with (df['ap_lo'] <= df['ap_hi']))
# - Systolic blood pressure= ap_hi        # Diastolic blood pressure= ap_lo
# - height is less than the 2.5th percentile (Keep the correct data with (df['height'] >= df['height'].quantile(0.025)))
# - height is more than the 97.5th percentile
# - weight is less than the 2.5th percentile
# - weight is more than the 97.5th percentile

# %%
medical_exam.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168      62    110     80            0     0      0
# 1   1  20228       1     156      85    140     90            1     0      0
# 2   2  18857       1     165      64    130     70            1     0      0
# 3   3  17623       2     169      82    150    100            0     0      0
# 4   4  17474       1     156      56    100     60            0     0      0
#
#    alco  active  cardio  Overweight
# 0     0       1       0           0
# 1     0       1       1           1
# 2     0       0       1           0
# 3     0       1       1           1
# 4     0       0       0           0

# %%
medical_exam.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349843    164.359229     74.204329
# std    28851.302323   2467.251667      0.477253      8.210126     14.395953
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      3.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      0.251643      0.150300      0.088129
# ...

# %%
min_threshold_height,max_threshold_height= medical_exam.height.quantile([0.025,0.975])
min_threshold_height,max_threshold_height
# Out:
# (150.0, 180.0)

# %%
min_threshold_weight,max_threshold_weight= medical_exam.weight.quantile([0.025,0.975])
min_threshold_weight,max_threshold_weight
# Out:
# (51.0, 108.0)

# %%
medical_exam_filtered=medical_exam[(medical_exam['height']<max_threshold_height) & (medical_exam['height']>min_threshold_height) & 
             (medical_exam['weight']<max_threshold_weight) & (medical_exam['weight']>min_threshold_weight) &
            (medical_exam['ap_lo']<=medical_exam['ap_hi'])]

# %%
medical_exam_filtered
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168      62    110     80            0     0
# 1          1  20228       1     156      85    140     90            1     0
# 2          2  18857       1     165      64    130     70            1     0
# 3          3  17623       2     169      82    150    100            0     0
# 4          4  17474       1     156      56    100     60            0     0
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69993  99991  19699       1     172      70    130     90            0     0
# 69994  99992  21074       1     165      80    150     80            0     0
# 69995  99993  19240       2     168      76    120     80            0     0
# 69998  99998  22431       1     163      72    135     80            0     1
# 69999  99999  20540       1     170      72    120     80            1     0
#
# ...

# %%
medical_exam_filtered.sample(10)
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 13059  18629  21308       1     159      87    140     90            0     1
# 53116  75770  20439       1     154      81    130     90            1     0
# 28994  41431  20305       1     173      78    120     80            0     0
# 2208    3119  20563       1     164     105    140     90            0     0
# 1959    2768  22603       1     158      66    120     80            1     0
# 31614  45136  21887       1     153      98    115     80            0     1
# 15238  21780  20426       1     165      86    120     80            0     0
# 688      973  19676       1     161      91    120     80            0     0
# 4137    5853  20322       2     176      84    150    100            0     1
# 50269  71740  14638       1     165      70    120     80            0     0
#
#        smoke  alco  active  cardio  Overweight
# 13059      0     0       1       1           1
# ...

# %%
medical_exam_filtered.isnull().values.any()
# Out:
# False

# %%
medical_exam_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61203 entries, 0 to 69999
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           61203 non-null  int64
#  1   age          61203 non-null  int64
#  2   gender       61203 non-null  int64
#  3   height       61203 non-null  int64
#  4   weight       61203 non-null  int64
#  5   ap_hi        61203 non-null  int64
#  6   ap_lo        61203 non-null  int64
#  7   cholesterol  61203 non-null  int64
#  8   gluc         61203 non-null  int64
#  9   smoke        61203 non-null  int64
#  10  alco         61203 non-null  int64
#  11  active       61203 non-null  int64
#  12  cardio       61203 non-null  int64
#  13  Overweight   61203 non-null  Int64
# dtypes: Int64(1), int64(13)
# memory usage: 7.1 MB

# %%
medical_exam_filtered.corr()
# Out:
#                    id       age    gender    height    weight     ap_hi  \
# id           1.000000  0.002719  0.004382  0.001933  0.000530  0.002985
# age          0.002719  1.000000 -0.014441 -0.073617  0.071631  0.020773
# gender       0.004382 -0.014441  1.000000  0.495365  0.119098  0.003407
# height       0.001933 -0.073617  0.495365  1.000000  0.235300  0.001723
# weight       0.000530  0.071631  0.119098  0.235300  1.000000  0.027689
# ap_hi        0.002985  0.020773  0.003407  0.001723  0.027689  1.000000
# ap_lo        0.001236  0.153205  0.060557  0.015728  0.226321  0.074573
# cholesterol  0.005438  0.128966 -0.035678 -0.060986  0.135945  0.024775
# gluc         0.003159  0.087782 -0.021433 -0.031992  0.104744  0.012198
# smoke       -0.001010 -0.041303  0.337765  0.183796  0.051597 -0.001730
# alco        -0.000335 -0.026521  0.167219  0.083503  0.056691  0.000941
# active       0.005457 -0.012401  0.009293 -0.002900 -0.012237 -0.000976
# ...

# %%
medical_exam_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61203 entries, 0 to 69999
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           61203 non-null  int64
#  1   age          61203 non-null  int64
#  2   gender       61203 non-null  int64
#  3   height       61203 non-null  int64
#  4   weight       61203 non-null  int64
#  5   ap_hi        61203 non-null  int64
#  6   ap_lo        61203 non-null  int64
#  7   cholesterol  61203 non-null  int64
#  8   gluc         61203 non-null  int64
#  9   smoke        61203 non-null  int64
#  10  alco         61203 non-null  int64
#  11  active       61203 non-null  int64
#  12  cardio       61203 non-null  int64
#  13  Overweight   61203 non-null  Int64
# dtypes: Int64(1), int64(13)
# memory usage: 7.1 MB

# %%
# Mask upper matrix
upp_mat = np.triu(medical_exam_filtered.corr())
# Fix the fif. size
f, ax = plt.subplots(figsize=(16, 12))
# Plot heatmap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(medical_exam_filtered.corr(), vmin = -.3, vmax = +.3, annot = True, cmap = 'RdBu', mask = upp_mat)
# Out:
# <AxesSubplot:>
